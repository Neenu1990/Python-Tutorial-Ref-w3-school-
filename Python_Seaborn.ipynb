# %% [markdown]
# # Seaborn
#
#  1. Seaborn, a popular data visualization library in Python.
#  2. Seaborn offers an easy-to-use interface for creating informative statistical graphics.
#  2. Seaborn library built on top of matplotlib.
#  3. It helps in identifying patterns, relationships, and trends that might not be apparent through raw data alone.
#  4. It is designed to work with Pandas dataframes, making it easy to visualize and explore data quickly and effectively.
#  5. Provides a range of tools for visualizing data, including advanced statistical analysis, and makes it
#     easy to create complex multi-plot visualizations.

# %% [markdown]
# ### Install seaborn

# %%
# install seaborn with pip
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importing  seaborn and dependencies

# %%
Seaborn has the following dependencies:– 

                   a. Python 2.7 or 3.4+
                   b. numpy
                   c. scipy
                   d. pandas
                   e. matplotlib
                
Here , we used alias name as 'sns' while importing seaborn.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Sample Datasets
#
#     Seaborn provides several built-in datasets that we can use for data visualization and statistical analysis.
# These datasets are stored in pandas dataframes, making them easy to use with Seaborn's plotting functions.
#
# Method used in seaborn to get  and load datasets:
#
#     1. get_dataset_names()  : Method to display all available datasets.
#     2. load_dataset()       : Method to load the specified dataset.This method takes the name of the dataset as argument.

# %% [markdown]
# ##### get_dataset_names()

# %%
# get_dataset_names() to display all the built-in datasets in Seaborn.

print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# ##### load_dataset()

# %% [markdown]
# ##### Example of loading 'tips' dataset.

# %%
#load_dataset() method to load 'tips' dataset.

tips_df = sns.load_dataset("tips")
tips_df.head(10) # head() method will return first 10 rows of the specified dataset.
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# ##### Another example of loading  dataset.

# %%
#load 'car_crashes' dataset()

crash_df = sns.load_dataset("car_crashes")
crash_df.head(10) # head() method will return first 10 rows of the specified dataset.
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
# 5   13.6     5.032    3.808          10.744       12.920       835.50
# 6   10.8     4.968    3.888           9.396        8.856      1068.73
# 7   16.2     6.156    4.860          14.094       16.038      1137.87
# 8    5.9     2.006    1.593           5.900        5.900      1273.89
# 9   17.9     3.759    5.191          16.468       16.826      1160.13
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
# 5      139.91     CO
# 6      167.02     CT
# ...

# %% [markdown]
# ### Seaborn Plot types

# %%
Seaborn provides a wide range of plot types that can be used for data visualization and analysis. Seaborn plots are
broadly classified into 6 types.

 1. Relational plots
 2. Distribution Plots
 3. Categorical plots
 4. Regression plots
 5. Matrix plots
 6. Multi-plot grids

They are again sudivided into different plots as given below:
    
1. Relational plots

      1.  Scatter Plot
      2.  Line Plot
      3.  rel plot
    
2. Distribution Plots  

      1. displot
      2. histplot
      3. kdeplot (Kernel Density Estimation)
      4. ecdfplot
      5. rugplot

3. Categorical plots

      1. catplot
      2. stripplot
      3. swarmplot
      4. boxplot
      5. violinplot
      6. boxenplot
      7. pointplot
      8. barplot
      9. countplot
    
 4. Regression plots

      1. lmplot
      2. regplot
      3. residplot
    
 5. Matrix plots

      1. heatmap
      2. clustermap
        
6. Multi-plot grids

      1. Facet grids
      2. Pair grids (pairplot , pairGrid)
      3. Joint grids(jointplot, jointGrid)

In this tutorial we will familiarize each plot with our built-in datasets.

# %% [markdown]
# ### Relational plots

# %%
      1.  Scatter Plot
      2.  Line Plot
      3.  rel plot

# %%
#sns.displot(crash_df['not_distracted'])
#plt.show()
sns.displot(crash_df['not_distracted'], kde=True, bins=25)
plt.show()
#sns.displot(crash_df['not_distracted'])

# %%
#sns.jointplot(data=crash_df, x= 'speeding',y='alcohol')
#plt.show()
#sns.jointplot(data=crash_df, x= 'speeding',y='alcohol', kind= 'kde', cmap='Reds',shade=True)
#plt.show()
sns.jointplot(data=crash_df, x= 'speeding',y='alcohol',kind= 'hex',color='red')
plt.show()

# %%
tips_df=sns.load_dataset('tips')
sns.pairplot(tips_df,hue='sex',palette='Reds')
plt.show()

# %%
sns.rugplot(tips_df['tip'])
plt.show()

# %%
sns.jointplot(data=crash_df, x= 'speeding',y='alcohol',kind= 'reg')

plt.figure(figsize=(8,4))
sns.set_style('dark')
#white,ticks,dark,whitegrid
sns.set_context('paper',font_scale=1.6)#poster,talk
plt.show()




#sns.despine(left=True,bottom=True, top=True)

# %%
#sns.barplot(data=tips_df, x='sex', y='total_bill')
#plt.show()
sns.barplot(data=tips_df, x='sex', y='total_bill', estimator=np.cov)
plt.show()

# %%
#sns.violinplot(data=tips_df,x='day',y='total_bill')
#plt.show()
#sns.violinplot(data=tips_df,x='day',y='total_bill',hue='sex')
#plt.show()
sns.violinplot(data=tips_df,x='day',y='total_bill',hue='sex',split=True)
plt.show()

# %%
#sns.stripplot(x='day',y='total_bill',data=tips_df)
#plt.show()

#sns.stripplot(x='day',y='total_bill',data=tips_df,jitter=True)
#plt.show()

#sns.stripplot(x='day',y='total_bill',data=tips_df,jitter=True, hue='sex')
#plt.show()

sns.stripplot(x='day',y='total_bill',data=tips_df,jitter=True, hue='sex',dodge=True)
plt.figure(figsize=(20,10))
plt.show()

# %%
#sns.swarmplot(data=tips_df,x='day',y='total_bill')
sns.violinplot(data=tips_df,x='day',y='total_bill')
#plt.show()
sns.swarmplot(data=tips_df,x='day',y='total_bill', color='white')
plt.show()

# %%
#sns.swarmplot(data=tips_df,x='day',y='total_bill')
sns.violinplot(data=tips_df,x='day',y='total_bill')
#plt.show()
sns.swarmplot(data=tips_df,x='day',y='total_bill', color='white')
plt.show()

# %%
crash_mx = crash_df.corr()
crash_mx

#plt.figure(figsize=(8,6))
#sns.set_context('paper', font_scale=1.4)
sns.heatmap(crash_mx, annot=True, cmap='Blues')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 crash_mx = crash_df.corr()
#       2 crash_mx
#       4 #plt.figure(figsize=(8,6))
#       5 #sns.set_context('paper', font_scale=1.4)
#
# NameError: name 'crash_df' is not defined

# %%
flights = sns.load_dataset('flights')
#flights

flights = flights.pivot_table(index = 'month', columns= 'year', values= 'passengers')


#sns.heatmap(flights, cmap = 'Blues')
sns.heatmap(flights, cmap = 'Blues',linecolor='White', linewidth=1)
plt.show()

# %%
sns.clustermap(flights,cmap='Blues',standard_scale=1)
plt.show()

# %%
# Form a facetgrid using columns with a hue
#tips_fg=sns.FacetGrid(tips_df,col='time', row= 'smoker')
tips_fg=sns.FacetGrid(tips_df,col='time', hue='smoker',height=5, aspect=1.5)

# map the above form facetgrid with some attributes
#tips_fg.map(plt.hist,'total_bill',bins=8)
tips_fg.map(plt.scatter,'total_bill','tip')
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', col='sex', row='time', data=tips_df)
plt.show()

# %% [markdown]
# ### Reference
# https://seaborn.pydata.org/index.html
